# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# !pip install -r "/content/drive/MyDrive/ChemXTree/MPNN/mpnn/requirements.txt"
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.4/166.4 kB 3.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.4/29.4 MB 49.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 113.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 14.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 7.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.5/30.5 MB 24.1 MB/s eta 0:00:00
# ...
#   Created wheel for typed-argument-parser: filename=typed_argument_parser-1.9.0-py3-none-any.whl size=25616 sha256=e5b4559a5c6de0fe1fc6ce8fc30d089c4a2f1aa92613ef99c2684660dd878ea8
#   Stored in directory: /root/.cache/pip/wheels/f0/94/0f/9539f578bed7e1bd423c702e403712f5ee8989f831a71db000
# Successfully built typed-argument-parser
# ...
#   Attempting uninstall: lightgbm
#     Found existing installation: lightgbm 4.1.0
#     Uninstalling lightgbm-4.1.0:
# ...

# %%
import sys
sys.path.append("/content/drive/MyDrive/ChemXTree/MPNN/mpnn/")
from MPNN_Pipeline import MPNNPipeline

# Global Variables
DATASET_NAME = "CYYYYY"
BASE_PATH = "/content/drive/MyDrive/ChemXTree/" + DATASET_NAME + "/"
CHECKPOINTS_DIR = BASE_PATH + DATASET_NAME + "_checkpoints"
train_file = f"{BASE_PATH}train{DATASET_NAME}.csv"
test_file = f"{BASE_PATH}test{DATASET_NAME}.csv"
val_file = f"{BASE_PATH}valid{DATASET_NAME}.csv"

# For Colab environment
# Note: The following code only runs in the Google Colab environment
pipeline_colab = MPNNPipeline(
    train_file=train_file,
    test_file=test_file,
    val_file=val_file,
    dataset_name=DATASET_NAME,
    checkpoints_dir=CHECKPOINTS_DIR,
    base_path=BASE_PATH,
    run_env='colab'
)
# Only uncomment the following and execute it in the Colab environment
pipeline_colab.run_pipeline()
# Out:
# Creating search space using parameters ['dropout', 'ffn_num_layers', 'depth', 'linked_hidden_size'].
# No manual trials loaded as part of hyperparameter search
# Initiating trial with seed 0
# Loaded 0 previous trials
# Parameters assigned with TPE directed search
#   0% 0/1 [00:00<?, ?trial/s, best loss=?]Command line
#
# python /usr/local/bin/chemprop_hyperopt --dataset_type classification --num_iters 1 --data_path /content/drive/MyDrive/mpnn_script/CYYYYY/trainCYYYYY.csv --config_save_path /content/drive/MyDrive/mpnn_script/CYYYYY/optimized_config.json
#
# Args
#
# {'activation': 'ReLU',
#  'adding_bond_types': True,
#  'adding_h': False,
#  'aggregation': 'mean',
#  'aggregation_norm': 100,
#  'atom_constraints': [],
#  'atom_descriptor_scaling': True,
#  'atom_descriptors': None,
#  'atom_descriptors_path': None,
#  'atom_descriptors_size': 0,
#  'atom_features_size': 0,
#  'atom_messages': False,
#  'atom_targets': [],
#  'batch_size': 50,
#  'bias': False,
# ...
